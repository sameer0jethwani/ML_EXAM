# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("student-mat.csv")

# %% [markdown]
# lets perform basic sanity to know about data and mistakes like missing value and etc

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# lets find rows and columns of dataframe

# %%
df.shape
# Out:
# (395, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %% [markdown]
# lets find if any has null values or missing values

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %% [markdown]
# data has no missing values

# %% [markdown]
# lets fix column names which are not right

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
#f=df.rename(columns={'school': 'SCHOOL','sex': 'SEX',"age":"AGE","address":"ADRESS","famsize":"FAMILY SIZE",""

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# lets drop which are not worth

# %%
df=df.drop(['famsize', 'address',"famrel","Dalc","Walc",], axis = 1)

# %%
df.head()
# Out:
#   school sex  age Pstatus  Medu  Fedu     Mjob      Fjob  reason guardian  \
# 0     GP   F   18       A     4     4  at_home   teacher  course   mother
# 1     GP   F   17       T     1     1  at_home     other  course   father
# 2     GP   F   15       T     1     1  at_home     other   other   mother
# 3     GP   F   15       T     4     2   health  services    home   mother
# 4     GP   F   16       T     3     3    other     other    home   father
#
#    ...  higher  internet  romantic freetime goout health absences  G1  G2  G3
# 0  ...     yes        no        no        3     4      3        6   5   6   6
# 1  ...     yes       yes        no        3     3      3        4   5   5   6
# 2  ...     yes       yes        no        3     2      3       10   7   8  10
# 3  ...     yes       yes       yes        2     2      5        2  15  14  15
# 4  ...     yes        no        no        3     2      5        4   6  10  10
#
# [5 rows x 28 columns]

# %%
df=df.drop(["romantic","famsup","reason"], axis = 1)

# %% [markdown]
# lets make some column names readbale

# %%
df.head()
# Out:
#   school sex  age Pstatus  Medu  Fedu     Mjob      Fjob guardian  traveltime  \
# 0     GP   F   18       A     4     4  at_home   teacher   mother           2
# 1     GP   F   17       T     1     1  at_home     other   father           1
# 2     GP   F   15       T     1     1  at_home     other   mother           1
# 3     GP   F   15       T     4     2   health  services   mother           1
# 4     GP   F   16       T     3     3    other     other   father           1
#
#    ...  nursery  higher internet freetime goout health absences  G1  G2  G3
# 0  ...      yes     yes       no        3     4      3        6   5   6   6
# 1  ...       no     yes      yes        3     3      3        4   5   5   6
# 2  ...      yes     yes      yes        3     2      3       10   7   8  10
# 3  ...      yes     yes      yes        2     2      5        2  15  14  15
# 4  ...      yes     yes       no        3     2      5        4   6  10  10
#
# [5 rows x 25 columns]

# %%
df=df.rename(columns={'school': 'SCHOOL','sex': 'SEX',"age":"AGE","Pstatus":"PARENT STATUS","Medu":"MOTHER EDUCATION"})

# %%
df=df.rename(columns={"Fedu":"FATHERS EDUCATION","Medu":"MOTHERS EDUCATION","Mjob":"MOTHER'S JOB"})

# %%
df.head()
# Out:
#   SCHOOL SEX  AGE PARENT STATUS  MOTHER EDUCATION  FATHERS EDUCATION  \
# 0     GP   F   18             A                 4                  4
# 1     GP   F   17             T                 1                  1
# 2     GP   F   15             T                 1                  1
# 3     GP   F   15             T                 4                  2
# 4     GP   F   16             T                 3                  3
#
#   MOTHER'S JOB      Fjob guardian  traveltime  ...  nursery  higher internet  \
# 0      at_home   teacher   mother           2  ...      yes     yes       no
# 1      at_home     other   father           1  ...       no     yes      yes
# 2      at_home     other   mother           1  ...      yes     yes      yes
# 3       health  services   mother           1  ...      yes     yes      yes
# 4        other     other   father           1  ...      yes     yes       no
#
#   freetime goout health absences  G1  G2  G3
# ...

# %%
df=df.rename(columns={"G1":"GRADE 1","G2":"GRADE 2","G3":"GRADE 3"})

# %%
df.head()
# Out:
#   SCHOOL SEX  AGE PARENT STATUS  MOTHER EDUCATION  FATHERS EDUCATION  \
# 0     GP   F   18             A                 4                  4
# 1     GP   F   17             T                 1                  1
# 2     GP   F   15             T                 1                  1
# 3     GP   F   15             T                 4                  2
# 4     GP   F   16             T                 3                  3
#
#   MOTHER'S JOB      Fjob guardian  traveltime  ...  nursery  higher internet  \
# 0      at_home   teacher   mother           2  ...      yes     yes       no
# 1      at_home     other   father           1  ...       no     yes      yes
# 2      at_home     other   mother           1  ...      yes     yes      yes
# 3       health  services   mother           1  ...      yes     yes      yes
# 4        other     other   father           1  ...      yes     yes       no
#
#   freetime goout health absences GRADE 1  GRADE 2  GRADE 3
# ...

# %% [markdown]
# lets sum up all the grades for better

# %%
df["TOTAL GRADES"]=df["GRADE 1"]+df["GRADE 2"]+df["GRADE 3"]

# %%
df.head()
# Out:
#   SCHOOL SEX  AGE PARENT STATUS  MOTHER EDUCATION  FATHERS EDUCATION  \
# 0     GP   F   18             A                 4                  4
# 1     GP   F   17             T                 1                  1
# 2     GP   F   15             T                 1                  1
# 3     GP   F   15             T                 4                  2
# 4     GP   F   16             T                 3                  3
#
#   MOTHER'S JOB      Fjob guardian  traveltime  ...  higher  internet freetime  \
# 0      at_home   teacher   mother           2  ...     yes        no        3
# 1      at_home     other   father           1  ...     yes       yes        3
# 2      at_home     other   mother           1  ...     yes       yes        3
# 3       health  services   mother           1  ...     yes       yes        2
# 4        other     other   father           1  ...     yes        no        3
#
#   goout health absences GRADE 1 GRADE 2  GRADE 3  TOTAL GRADES
# ...

# %% [markdown]
# NOW LETS DROP GRADE 1 , GRADE 2 , GRADE 3 AS WE GOT TOTAL GRADES

# %%
df=df.drop(["GRADE 1","GRADE 2","GRADE 3"], axis = 1)

# %%
df.head()
# Out:
#   SCHOOL SEX  AGE PARENT STATUS  MOTHER EDUCATION  FATHERS EDUCATION  \
# 0     GP   F   18             A                 4                  4
# 1     GP   F   17             T                 1                  1
# 2     GP   F   15             T                 1                  1
# 3     GP   F   15             T                 4                  2
# 4     GP   F   16             T                 3                  3
#
#   MOTHER'S JOB      Fjob guardian  traveltime  ...  paid  activities nursery  \
# 0      at_home   teacher   mother           2  ...    no          no     yes
# 1      at_home     other   father           1  ...    no          no      no
# 2      at_home     other   mother           1  ...   yes          no     yes
# 3       health  services   mother           1  ...   yes         yes     yes
# 4        other     other   father           1  ...   yes          no     yes
#
#   higher internet freetime goout health  absences  TOTAL GRADES
# ...

# %%
df=df.rename(columns={"Fjob":"FATHERS JOB","guardian":"GUARDIAN","paid":"PAID"})

# %%
df=df.rename(columns={"freetime":"FREE TIME","go out":"GO OUT","health":"HEALTH","absences":"ABSENCES"})

# %%
df.head()
# Out:
#   SCHOOL SEX  AGE PARENT STATUS  MOTHER EDUCATION  FATHERS EDUCATION  \
# 0     GP   F   18             A                 4                  4
# 1     GP   F   17             T                 1                  1
# 2     GP   F   15             T                 1                  1
# 3     GP   F   15             T                 4                  2
# 4     GP   F   16             T                 3                  3
#
#   MOTHER'S JOB FATHERS JOB GUARDIAN  traveltime  ...  PAID  activities  \
# 0      at_home     teacher   mother           2  ...    no          no
# 1      at_home       other   father           1  ...    no          no
# 2      at_home       other   mother           1  ...   yes          no
# 3       health    services   mother           1  ...   yes         yes
# 4        other       other   father           1  ...   yes          no
#
#   nursery higher internet FREE TIME goout HEALTH  ABSENCES  TOTAL GRADES
# ...

# %%
df=df.drop(["higher","PARENT STATUS","schoolsup","PAID"], axis = 1)

# %%
df["SCHOOL"].unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %% [markdown]
# so data has 2 schools

# %% [markdown]
# # performing EDA

# %%
sns.pairplot(df)

# %%
#lets see GRADES effect from MOTHERS JOB
sns.barplot(x ="MOTHER'S JOB", y ='TOTAL GRADES', data = df, palette ='plasma')
# Out:
# <AxesSubplot:xlabel="MOTHER'S JOB", ylabel='TOTAL GRADES'>

# %% [markdown]
# YOU CAN SEE MOTHER WORKING IN HEALTH DEPARTMENT HAVE TALENTED CHILDREN

# %%
df.head()
# Out:
#   SCHOOL SEX  AGE  MOTHER EDUCATION  FATHERS EDUCATION MOTHER'S JOB  \
# 0     GP   F   18                 4                  4      at_home
# 1     GP   F   17                 1                  1      at_home
# 2     GP   F   15                 1                  1      at_home
# 3     GP   F   15                 4                  2       health
# 4     GP   F   16                 3                  3        other
#
#   FATHERS JOB GUARDIAN  traveltime  studytime  failures activities nursery  \
# 0     teacher   mother           2          2         0         no     yes
# 1       other   father           1          2         0         no      no
# 2       other   mother           1          2         3         no     yes
# 3    services   mother           1          3         0        yes     yes
# 4       other   father           1          2         0         no     yes
#
#   internet  FREE TIME  goout  HEALTH  ABSENCES  TOTAL GRADES
# ...

# %%
sns.barplot(x ="SCHOOL", y ='TOTAL GRADES', data = df, palette ='plasma')
# Out:
# <AxesSubplot:xlabel='SCHOOL', ylabel='TOTAL GRADES'>

# %% [markdown]
# you can see GP has higher GRADES Students , so may be GP education is better than "MS"

# %% [markdown]
# NOW LETS FIT NECESSARY FOR MACHINE LEARNING

# %%
df=df[["SCHOOL","traveltime","studytime","internet","TOTAL GRADES"]]

# %%
df.head()
# Out:
#   SCHOOL  traveltime  studytime internet  TOTAL GRADES
# 0     GP           2          2       no            17
# 1     GP           1          2      yes            16
# 2     GP           1          2      yes            25
# 3     GP           1          3      yes            44
# 4     GP           1          2       no            26

# %%
df=df.rename(columns={"traveltime":"TRAVEL TIME","studytime":"STUDY TIME","internet":"INTERNET"})

# %%
df.head()
# Out:
#   SCHOOL  TRAVEL TIME  STUDY TIME INTERNET  TOTAL GRADES
# 0     GP            2           2       no            17
# 1     GP            1           2      yes            16
# 2     GP            1           2      yes            25
# 3     GP            1           3      yes            44
# 4     GP            1           2       no            26

# %% [markdown]
# # identifying x and y

# %%
x=df.drop(["TOTAL GRADES"], axis = 1)

# %%
x
# Out:
#     SCHOOL  TRAVEL TIME  STUDY TIME INTERNET
# 0       GP            2           2       no
# 1       GP            1           2      yes
# 2       GP            1           2      yes
# 3       GP            1           3      yes
# 4       GP            1           2       no
# ..     ...          ...         ...      ...
# 390     MS            1           2       no
# 391     MS            2           1      yes
# 392     MS            1           1       no
# 393     MS            3           1      yes
# 394     MS            1           1      yes
#
# [395 rows x 4 columns]

# %%
y=df[["TOTAL GRADES"]]

# %%
y
# Out:
#      TOTAL GRADES
# 0              17
# 1              16
# 2              25
# 3              44
# 4              26
# ..            ...
# 390            27
# 391            46
# 392            25
# 393            33
# 394            26
#
# [395 rows x 1 columns]

# %% [markdown]
# # splitting into train and test

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3 ,random_state = 2)

# %% [markdown]
# # lets train the model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-c455056c57cc> in <module>
#       2 model = LinearRegression()
#       3
# ----> 4 model.fit(x_train,y_train)
#
# c:\users\sam\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# c:\users\sam\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# ...
